# %%
# creating a cars list

# %%
cars=['suzuki','hyundai','benz','kia','bmw','mahendra','audi']
print(cars)
# Out:
# ['suzuki', 'hyundai', 'benz', 'kia', 'bmw', 'mahendra', 'audi']

# %%
# i want organise the above list in a alphabetical order ( a - Z order)

1.permanent approach 
# changes are implied permanently (sorted)

2.temp approach
# No changes are applied we can have the orginal order(sorted)

# %%
print(sorted(cars))
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'mahendra', 'suzuki']

# %%
print(cars) # this is the orginal order
# Out:
# ['suzuki', 'hyundai', 'benz', 'kia', 'bmw', 'mahendra', 'audi']

# %%
cars.sort()
print(cars)
# Out:
# ['audi', 'benz', 'bmw', 'hyundai', 'kia', 'mahendra', 'suzuki']

# %%
# i want to print the entire list in the reverse order 

cars.reverse()
print(cars)
# Out:
# ['suzuki', 'mahendra', 'kia', 'hyundai', 'bmw', 'benz', 'audi']
